# %%
import pandas as pd
import numpy as np

# %%
from pandas import read_html

# %%
url = "http://www.fdic.gov/bank/individual/failed/banklist.html"

# %%
# pip install beautiful-soup
# pip install html5lib

# %%
dframe_list = pd.io.html.read_html(url)

# %%
dframe = dframe_list[0]

# %%
dframe.head()
# Out:
#                              Bank Name     City  ST   CERT  \
# 0     City National Bank of New Jersey   Newark  NJ  21111
# 1                        Resolute Bank   Maumee  OH  58317
# 2                Louisa Community Bank   Louisa  KY  58112
# 3                 The Enloe State Bank   Cooper  TX  10716
# 4  Washington Federal Bank for Savings  Chicago  IL  30570
#
#                Acquiring Institution       Closing Date       Updated Date
# 0                    Industrial Bank   November 1, 2019   November 7, 2019
# 1                 Buckeye State Bank   October 25, 2019  November 12, 2019
# 2  Kentucky Farmers Bank Corporation   October 25, 2019   November 7, 2019
# 3                 Legend Bank, N. A.       May 31, 2019    August 22, 2019
# 4                 Royal Savings Bank  December 15, 2017      July 24, 2019

# %%
dframe_list1 = pd.io.html.read_html('https://www.google.com/')

# %%
dframe_list1
# Out:
# [    0                                                  1  \
#  0 NaN  (function(){var id='tsuid1';document.getElemen...
#
#                                 2
#  0  Advanced searchLanguage tools  ]

# %%
dframe_list2 = pd.io.html.read_html('https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India#Prime_Ministers_of_India')

# %%
len(dframe_list2)
# Out:
# 7

# %%
len(dframe_list2[0])
# Out:
# 8

# %%
dframe_list2[4].loc[1]
# Out:
# 0    Interim Nehru I Nehru II Nehru III Nehru IV Sh...
# Name: 1, dtype: object

# %%
dd = pd.read_html('https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India#Prime_Ministers_of_India')

# %%
len(dd)
# Out:
# 7

# %%
print dd[0].loc[1, 0]
# Out:
# This article is part of a series on thepolitics and government ofIndia

# %%
dd[0]
# Out:
#                                                    0
# 0                                              India
# 1  This article is part of a series on thepolitic...
# 2  Constitution and law Constitutional amendment ...
# 3  Government of India President (Head of state) ...
# 4  ElectionsElection commission: Chief election c...
# 5  Federalism Administrative divisions States and...
# 6                              Other countries Atlas
# 7                                                vte

# %%
dd[1]
# Out:
#                                                    0  \
# 0  Colour key for party of the prime ministers   ...
#
#                                                    1
# 0  Other key №: Incumbent number † Assassinated o...

# %%
dd[2]
# Out:
#                            0                                     1   \
# 0                         No.                                  Name
# 1                           1           Jawaharlal Nehru(1889–1964)
# 2               15 April 1952                         17 April 1957
# 3               17 April 1957                          2 April 1962
# 4                2 April 1962                        27 May 1964[†]
# 5                           –  Gulzarilal Nanda (acting)(1898–1998)
# 6                           2        Lal Bahadur Shastri(1904–1966)
# 7                           –  Gulzarilal Nanda (acting)(1898–1998)
# 8                           3              Indira Gandhi(1917–1984)
# 9   Rae Bareli, Uttar Pradesh                          4 March 1967
# 10              15 March 1971                         24 March 1977
# 11                          4              Morarji Desai(1896–1995)
# 12                          5               Charan Singh(1902–1987)
# ...
